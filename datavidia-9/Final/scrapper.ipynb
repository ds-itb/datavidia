# %%
# Author: Muhammad Fathur Rizky

# %%
import os
import requests
import gzip
import shutil
from bs4 import BeautifulSoup
from urllib.parse import urljoin

BASE_URL = "https://insideairbnb.com/get-the-data/"

response = requests.get(BASE_URL)
response.raise_for_status()

soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table', class_='data')
cities = []

for table in tables:
    rows = table.select('tbody tr')
    for row in rows:
        cols = row.find_all('td')
        if cols:
            city = cols[0].text.strip()
            if city and city not in cities:
                cities.append(city)

print(cities)
# Out:
# ['Trentino', 'Twin Cities MSA', 'Valencia', 'Vancouver', 'Vaud', 'Venice', 'Victoria', 'Vienna', 'Washington, D.C.', 'Western Australia', 'Winnipeg', 'Zurich', 'Ireland', 'Malta', 'New Zealand']
# 0

# %%
for table in tables:
    rows = table.select('tbody tr')[:3]
    
    for row in rows:
        cols = row.find_all('td')
        if len(cols) < 2:
            continue 
        
        city = cols[0].text.strip()
        link_tag = cols[1].find('a')
        if not link_tag:
            continue
        
        file_url = urljoin(BASE_URL, link_tag['href'].strip())
        filename = link_tag.text.strip()

        safe_city = city.replace('/', '_').replace('\\', '_')
            
        os.makedirs(safe_city, exist_ok=True)
        file_path = os.path.join(safe_city, filename)

        print(f"Downloading {file_url} -> {file_path}")
        try:
            file_response = requests.get(file_url)
            file_response.raise_for_status()
            with open(file_path, 'wb') as f:
                f.write(file_response.content)
        except Exception as e:
            print(f"Failed to download {file_url}: {e}")
            continue
        
        if file_path.endswith('.gz'):
            extracted_csv_path = file_path[:-3]
            print(f"Extracting {file_path} -> {extracted_csv_path}")
            try:
                with gzip.open(file_path, 'rb') as f_in:
                    with open(extracted_csv_path, 'wb') as f_out:
                        shutil.copyfileobj(f_in, f_out)
                os.remove(file_path)
            except Exception as e:
                print(f"Failed to extract {file_path}: {e}")

print("All downloads and extractions complete.")
# Out:
# Downloading https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/listings.csv.gz -> Trentino\listings.csv.gz
# Failed to download https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/listings.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/italy/trentino-alto-adige-s%C3%83%C2%BCdtirol/trentino/2024-12-31/data/listings.csv.gz
# Downloading https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/calendar.csv.gz -> Trentino\calendar.csv.gz
# Failed to download https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/calendar.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/italy/trentino-alto-adige-s%C3%83%C2%BCdtirol/trentino/2024-12-31/data/calendar.csv.gz
# Downloading https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/reviews.csv.gz -> Trentino\reviews.csv.gz
# Failed to download https://data.insideairbnb.com/italy/trentino-alto-adige-sÃ¼dtirol/trentino/2024-12-31/data/reviews.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/italy/trentino-alto-adige-s%C3%83%C2%BCdtirol/trentino/2024-12-31/data/reviews.csv.gz
# Downloading https://data.insideairbnb.com/united-states/mn/twin-cities-msa/2025-03-16/data/listings.csv.gz -> Twin Cities MSA\listings.csv.gz
# Extracting Twin Cities MSA\listings.csv.gz -> Twin Cities MSA\listings.csv
# Downloading https://data.insideairbnb.com/united-states/mn/twin-cities-msa/2025-03-16/data/calendar.csv.gz -> Twin Cities MSA\calendar.csv.gz
# Extracting Twin Cities MSA\calendar.csv.gz -> Twin Cities MSA\calendar.csv
# Downloading https://data.insideairbnb.com/united-states/mn/twin-cities-msa/2025-03-16/data/reviews.csv.gz -> Twin Cities MSA\reviews.csv.gz
# Extracting Twin Cities MSA\reviews.csv.gz -> Twin Cities MSA\reviews.csv
# Downloading https://data.insideairbnb.com/spain/vc/valencia/2025-03-15/data/listings.csv.gz -> Valencia\listings.csv.gz
# Extracting Valencia\listings.csv.gz -> Valencia\listings.csv
# Downloading https://data.insideairbnb.com/spain/vc/valencia/2025-03-15/data/calendar.csv.gz -> Valencia\calendar.csv.gz
# Extracting Valencia\calendar.csv.gz -> Valencia\calendar.csv
# Downloading https://data.insideairbnb.com/spain/vc/valencia/2025-03-15/data/reviews.csv.gz -> Valencia\reviews.csv.gz
# Extracting Valencia\reviews.csv.gz -> Valencia\reviews.csv
# Downloading https://data.insideairbnb.com/canada/bc/vancouver/2025-03-05/data/listings.csv.gz -> Vancouver\listings.csv.gz
# Extracting Vancouver\listings.csv.gz -> Vancouver\listings.csv
# Downloading https://data.insideairbnb.com/canada/bc/vancouver/2025-03-05/data/calendar.csv.gz -> Vancouver\calendar.csv.gz
# Extracting Vancouver\calendar.csv.gz -> Vancouver\calendar.csv
# Downloading https://data.insideairbnb.com/canada/bc/vancouver/2025-03-05/data/reviews.csv.gz -> Vancouver\reviews.csv.gz
# Extracting Vancouver\reviews.csv.gz -> Vancouver\reviews.csv
# Downloading https://data.insideairbnb.com/switzerland/vd/vaud/2025-03-01/data/listings.csv.gz -> Vaud\listings.csv.gz
# Extracting Vaud\listings.csv.gz -> Vaud\listings.csv
# Downloading https://data.insideairbnb.com/switzerland/vd/vaud/2025-03-01/data/calendar.csv.gz -> Vaud\calendar.csv.gz
# Extracting Vaud\calendar.csv.gz -> Vaud\calendar.csv
# Downloading https://data.insideairbnb.com/switzerland/vd/vaud/2025-03-01/data/reviews.csv.gz -> Vaud\reviews.csv.gz
# Extracting Vaud\reviews.csv.gz -> Vaud\reviews.csv
# Downloading https://data.insideairbnb.com/italy/veneto/venice/2025-03-02/data/listings.csv.gz -> Venice\listings.csv.gz
# Extracting Venice\listings.csv.gz -> Venice\listings.csv
# Downloading https://data.insideairbnb.com/italy/veneto/venice/2025-03-02/data/calendar.csv.gz -> Venice\calendar.csv.gz
# Extracting Venice\calendar.csv.gz -> Venice\calendar.csv
# Downloading https://data.insideairbnb.com/italy/veneto/venice/2025-03-02/data/reviews.csv.gz -> Venice\reviews.csv.gz
# Extracting Venice\reviews.csv.gz -> Venice\reviews.csv
# Downloading https://data.insideairbnb.com/canada/bc/victoria/2025-02-21/data/listings.csv.gz -> Victoria\listings.csv.gz
# Extracting Victoria\listings.csv.gz -> Victoria\listings.csv
# Downloading https://data.insideairbnb.com/canada/bc/victoria/2025-02-21/data/calendar.csv.gz -> Victoria\calendar.csv.gz
# Extracting Victoria\calendar.csv.gz -> Victoria\calendar.csv
# Downloading https://data.insideairbnb.com/canada/bc/victoria/2025-02-21/data/reviews.csv.gz -> Victoria\reviews.csv.gz
# Extracting Victoria\reviews.csv.gz -> Victoria\reviews.csv
# Downloading https://data.insideairbnb.com/austria/vienna/vienna/2025-03-05/data/listings.csv.gz -> Vienna\listings.csv.gz
# Extracting Vienna\listings.csv.gz -> Vienna\listings.csv
# Downloading https://data.insideairbnb.com/austria/vienna/vienna/2025-03-05/data/calendar.csv.gz -> Vienna\calendar.csv.gz
# Extracting Vienna\calendar.csv.gz -> Vienna\calendar.csv
# Downloading https://data.insideairbnb.com/austria/vienna/vienna/2025-03-05/data/reviews.csv.gz -> Vienna\reviews.csv.gz
# Extracting Vienna\reviews.csv.gz -> Vienna\reviews.csv
# Downloading https://data.insideairbnb.com/united-states/dc/washington-dc/2025-03-13/data/listings.csv.gz -> Washington, D.C.\listings.csv.gz
# Extracting Washington, D.C.\listings.csv.gz -> Washington, D.C.\listings.csv
# Downloading https://data.insideairbnb.com/united-states/dc/washington-dc/2025-03-13/data/calendar.csv.gz -> Washington, D.C.\calendar.csv.gz
# Extracting Washington, D.C.\calendar.csv.gz -> Washington, D.C.\calendar.csv
# Downloading https://data.insideairbnb.com/united-states/dc/washington-dc/2025-03-13/data/reviews.csv.gz -> Washington, D.C.\reviews.csv.gz
# Extracting Washington, D.C.\reviews.csv.gz -> Washington, D.C.\reviews.csv
# Downloading https://data.insideairbnb.com/australia/wa/western-australia/2024-12-25/data/listings.csv.gz -> Western Australia\listings.csv.gz
# Extracting Western Australia\listings.csv.gz -> Western Australia\listings.csv
# Downloading https://data.insideairbnb.com/australia/wa/western-australia/2024-12-25/data/calendar.csv.gz -> Western Australia\calendar.csv.gz
# Extracting Western Australia\calendar.csv.gz -> Western Australia\calendar.csv
# Downloading https://data.insideairbnb.com/australia/wa/western-australia/2024-12-25/data/reviews.csv.gz -> Western Australia\reviews.csv.gz
# Extracting Western Australia\reviews.csv.gz -> Western Australia\reviews.csv
# Downloading https://data.insideairbnb.com/canada/mb/winnipeg/2025-03-07/data/listings.csv.gz -> Winnipeg\listings.csv.gz
# Extracting Winnipeg\listings.csv.gz -> Winnipeg\listings.csv
# Downloading https://data.insideairbnb.com/canada/mb/winnipeg/2025-03-07/data/calendar.csv.gz -> Winnipeg\calendar.csv.gz
# Extracting Winnipeg\calendar.csv.gz -> Winnipeg\calendar.csv
# Downloading https://data.insideairbnb.com/canada/mb/winnipeg/2025-03-07/data/reviews.csv.gz -> Winnipeg\reviews.csv.gz
# Extracting Winnipeg\reviews.csv.gz -> Winnipeg\reviews.csv
# Downloading https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/listings.csv.gz -> Zurich\listings.csv.gz
# Failed to download https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/listings.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/switzerland/z%C3%83%C2%BCrich/zurich/2024-12-30/data/listings.csv.gz
# Downloading https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/calendar.csv.gz -> Zurich\calendar.csv.gz
# Failed to download https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/calendar.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/switzerland/z%C3%83%C2%BCrich/zurich/2024-12-30/data/calendar.csv.gz
# Downloading https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/reviews.csv.gz -> Zurich\reviews.csv.gz
# Failed to download https://data.insideairbnb.com/switzerland/zÃ¼rich/zurich/2024-12-30/data/reviews.csv.gz: 403 Client Error: Forbidden for url: https://data.insideairbnb.com/switzerland/z%C3%83%C2%BCrich/zurich/2024-12-30/data/reviews.csv.gz
# Downloading https://data.insideairbnb.com/ireland/2024-12-12/data/listings.csv.gz -> Ireland\listings.csv.gz
# Extracting Ireland\listings.csv.gz -> Ireland\listings.csv
# Downloading https://data.insideairbnb.com/ireland/2024-12-12/data/calendar.csv.gz -> Ireland\calendar.csv.gz
# Extracting Ireland\calendar.csv.gz -> Ireland\calendar.csv
# Downloading https://data.insideairbnb.com/ireland/2024-12-12/data/reviews.csv.gz -> Ireland\reviews.csv.gz
# Extracting Ireland\reviews.csv.gz -> Ireland\reviews.csv
# Downloading https://data.insideairbnb.com/malta/2024-12-23/data/listings.csv.gz -> Malta\listings.csv.gz
# Extracting Malta\listings.csv.gz -> Malta\listings.csv
# Downloading https://data.insideairbnb.com/malta/2024-12-23/data/calendar.csv.gz -> Malta\calendar.csv.gz
# Extracting Malta\calendar.csv.gz -> Malta\calendar.csv
# Downloading https://data.insideairbnb.com/malta/2024-12-23/data/reviews.csv.gz -> Malta\reviews.csv.gz
# Extracting Malta\reviews.csv.gz -> Malta\reviews.csv
# Downloading https://data.insideairbnb.com/new-zealand/2025-03-05/data/listings.csv.gz -> New Zealand\listings.csv.gz
# Extracting New Zealand\listings.csv.gz -> New Zealand\listings.csv
# Downloading https://data.insideairbnb.com/new-zealand/2025-03-05/data/calendar.csv.gz -> New Zealand\calendar.csv.gz
# Extracting New Zealand\calendar.csv.gz -> New Zealand\calendar.csv
# Downloading https://data.insideairbnb.com/new-zealand/2025-03-05/data/reviews.csv.gz -> New Zealand\reviews.csv.gz
# Extracting New Zealand\reviews.csv.gz -> New Zealand\reviews.csv
# ✅ All downloads and extractions complete.
