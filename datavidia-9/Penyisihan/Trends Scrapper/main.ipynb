# %%
# !pip install selenium==4.9.0 numpy==1.24.3 pandas==1.5.3
# Out:
# ...
#   Using cached selenium-4.9.0-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached numpy-1.24.3.tar.gz (10.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Ellipsis\anaconda3\envs\DATAVIDIA\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Ellipsis\anaconda3\envs\DATAVIDIA\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\Ellipsis\anaconda3\envs\DATAVIDIA\Lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
# ...

# %%
from src.GoogleTrendsScraper import GoogleTrendsScraper
import os

gts = GoogleTrendsScraper(sleep=5, path_driver=r"C:\Users\Ellipsis\Downloads\chromedriver_win32\chromedriver.exe", headless=True)
keywords = [
    "bawang merah",
    "bawang putih",
    "bawang",
    "beras",
    "cabai merah",
    "cabai rawit",
    "cabai",
    "daging ayam",
    "daging sapi",
    "daging",
    "gula",
    "minyak goreng",
    "telur ayam",
    "tepung terigu"
]

start_date = "2022-01-01"
end_date = "2024-12-31"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.GoogleTrendsScraper import GoogleTrendsScraper
#       2 import os
#       4 gts = GoogleTrendsScraper(sleep=5, path_driver=r"C:\Users\Ellipsis\Downloads\chromedriver_win32\chromedriver.exe", headless=True)
#
# File c:\Users\Ellipsis\Documents\GoogleTrends-Scraper\src\GoogleTrendsScraper.py:1
# ----> 1 import pandas as pd
#       2 import time
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'
